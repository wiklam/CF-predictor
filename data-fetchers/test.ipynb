# %%
from database import *

# %%
AllUserFetch()

# %%
ContestFetch()
# Out:
# Contests left 1098 1466
# Contests left 1097 1411
# Contests left 1096 1464
# Contests left 1095 1465
# Contests left 1094 1458
# Contests left 1093 1459
# Contests left 1092 1410
# Contests left 1091 1461
# Contests left 1090 1450
# Contests left 1089 1453
# Contests left 1088 1415
# Contests left 1087 1456
# Contests left 1086 1457
# Contests left 1085 1414
# Contests left 1084 1451
# Contests left 1083 1439
# Contests left 1082 1440
# Contests left 1081 1446
# Contests left 1080 1447
# Contests left 1079 1438
# Contests left 1078 1442
# Contests left 1077 1443
# Contests left 1076 1441
# Contests left 1075 1444
# Contests left 1074 1445
# Contests left 1073 1413
# Contests left 1072 1434
# Contests left 1071 1435
# Contests left 1070 1436
# Contests left 1069 1412
# Contests left 1068 1421
# Contests left 1067 1428
# Contests left 1066 1427
# Contests left 1065 1422
# Contests left 1064 1408
# Contests left 1063 1416
# Contests left 1062 1417
# Contests left 1061 1420
# ...

# %%
CreateDataBase()
# Out:
# loading

# %%
db = LoadDataBase()

# %%
'szymonkot1' in db.getActiveUsers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6ed470dd2b47> in <module>
# ----> 1 'szymonkot1' in db.getActiveUsers()
#
# ~/desktop/programs/studia/ml/project/cf-predictor/data-fetchers/database.py in getActiveUsers(self)
#     110
#     111     def getUsers(self):
# --> 112         return self.users.keys()
#     113
#     114     def getActiveUsers(self):
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
print(len(db.contestHistory))
# Out:
# 26045

# %%
for contest in db.contests:
    print(contest, db.contests[contest])
# Out:
# 1466 duration: 3h 00m, startTime: 1609338900s, authors: ['Anadi', 'Okrut', 'gawry']
# 1411 duration: 2h 00m, startTime: 1608476700s, authors: ['neckbotov', 'sincerity']
# 1464 duration: 2h 00m, startTime: 1608476700s, authors: ['neckbotov', 'sincerity']
# 1465 duration: 2h 00m, startTime: 1608476700s, authors: ['neckbotov', 'sincerity']
# 1458 duration: 2h 00m, startTime: 1608370500s, authors: ['AndreySergunin', 'Endagorion', 'amethyst0']
# 1459 duration: 2h 00m, startTime: 1608370500s, authors: ['AndreySergunin', 'Endagorion', 'amethyst0']
# 1410 duration: 48h 00m, startTime: 1608300300s
# 1461 duration: 2h 00m, startTime: 1607697300s, authors: ['AleXman111', 'Vladik', 'netman', 'sdryapko']
# 1450 duration: 3h 00m, startTime: 1607265300s, authors: ['1-gon', 'Devil', 'fivefourthreeone']
# 1453 duration: 2h 15m, startTime: 1607087100s, authors: ['djm03178']
# ...
