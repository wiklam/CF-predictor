# %% [markdown]
# ### Elo Rating system
# This is AtCoder rating system implementation. We are trying to compare it to CodeForces rating system and try to improve it - find the best parameters for this system.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from database import Database, LoadDatabase
import numpy as np
import scipy as sp
import pickle, time, math, bz2, os

# %% [markdown]
# ### Elo Rating function

# %%
# return value: ans, userRatings
#   ans - dict of contestId: average error of expected ranking
#   userRatings: dict of handle: inner rating class with EloRating specific measures
# parameters:
#   - consider: eg. consider=50, will consider only 50 first contests (-1 means consider all)
#   - verbose: print verbosely
#   - basicRating: Ranking with which the user is starting
#   - k: constant scaling how many points will be gained in a duel
#   - eloConst1: constant by which the rating difference is divided in sigmoid function
#   - eloConst2: consant which is raised to the power in sigmoid function - does not have any real impact

def EloRatingSystem(data, consider=50, verbose=False, basicRating = 1200, k = 1, eloConst1 = 400, errFunc=None, **kwargs):

    class Rating:
        def __init__(self):
            self.ratings = []
        
        def getRating(self):
            if len(self.ratings) == 0:
                return basicRating
            return self.ratings[len(self.ratings)-1]

        def addRating(self, rating):
            self.ratings.append(rating)

    userRatings = {}

    def addNewUsers(standings):
        for handle in standings.index:
            if not handle in userRatings:
                userRatings[handle] = Rating()

    def getRatings(standings):
        return [(handle, userRatings[handle].getRating()) for handle in standings.index]

    def calcEloDiff(myRating, enemyRating, myRank1, enemyRank):
        exp = (enemyRating - myRating) / eloConst1
        expectedScore = 1/(1 + 10**exp)

        score = 0
        if myRank1 < enemyRank:
            score = 1
        elif myRank1 == enemyRank:
            score = 0.5

        return k * (score - expectedScore)


    def calcNewRating(handle, ranksAndRatings):
        oldRating = userRatings[handle].getRating()
        rank = standings.loc[handle]["rank"]
        diff = 0

        for enemyRank, enemyRating in ranksAndRatings:
            diff += calcEloDiff(oldRating, enemyRating, rank, enemyRank)
        # Removing diff from myself    
        diff -= calcEloDiff(oldRating, oldRating, rank, rank)
        #diff /= (len(standings.index) - 1) 
        # it was used before when we treated
        # contest as one match for a participant
        
        
        return oldRating + diff

    def calcExpectedRanksFromRatings(ratings):
        sortedRatings = sorted(ratings, key=lambda x: -x[1])
        ranks = np.empty(len(sortedRatings))
        i = 0
        while i < len(ranks):
            j = i
            rating = sortedRatings[i][1]
            while j + 1 < len(ranks) and sortedRatings[j + 1][1] == rating:
                j += 1
            ranks[i:j+1] = (i + 1 + j + 1) / 2
            i = j + 1
        return [(handle, ranks[i]) for i, (handle, _) in enumerate(sortedRatings)]

    def calcErrorRate(expectedRanks, standings):
        res = []
        if(errFunc is None):
            for handle, rank in expectedRanks:
                res += abs(rank - standings.loc[handle]["rank"])
        else:
            for errorFunc in errFunc:
                error = 0
                for handle, rank in expectedRanks:
                    error += errorFunc(rank, standings.loc[handle]["rank"])
                res.append(error / len(expectedRanks))
        return res

    
    sortedStandings = [(k,v) for k,v in sorted(data.standings.items(),
                        key=lambda x: data.contests.loc[x[0]].startTime)]
    if consider != -1:
        sortedStandings = sortedStandings[:consider]
    standingsLeft = len(sortedStandings)
    ans = {}

    for contestId, standings in sortedStandings:
        standings = standings.copy()
        if verbose:
            print("Standings left:", standingsLeft, "contestId:", contestId)
        standingsLeft -= 1
        addNewUsers(standings)
        ratings = getRatings(standings)
        expectedRanks = calcExpectedRanksFromRatings(ratings)
        ans[contestId] = calcErrorRate(expectedRanks, standings)

        ratingUpdate = {}
        ranksAndRatings = []
        
        for handle in standings.index:
            rating = userRatings[handle].getRating()
            ranks = standings.loc[handle]["rank"]
            ranksAndRatings.append([ranks, rating])
        
        for handle in standings.index:
            newrating = calcNewRating(handle, ranksAndRatings)
            ratingUpdate[handle] = newrating

        for handle in standings.index:
            userRatings[handle].addRating(ratingUpdate[handle])
    
    errDict = {}
    errDict['basic'] = ans
    if errFunc != None:
        errDict = {}
        itera = 0
        for errorFunc in errFunc:
            specErr = {}
            for contestId, standings in sortedStandings:
                specErr[contestId] = ans[contestId][itera]
            itera += 1
            errDict[errorFunc.__name__] = specErr

    return errDict, userRatings

# %% [markdown]
# ### error functions

# %%
def sqrt_err(x, y):
    return np.sqrt(np.abs(x - y))

def linear_err(x, y):
    return np.abs(x - y)

def squared_err(x, y):
    return np.power(x - y, 2)

def log_err(x, y):
    return np.abs(np.log(x) - np.log(y))

all_err_funs = [sqrt_err, linear_err, log_err]
all_err_fun_names = [err_f.__name__ for err_f in all_err_funs]

# %%
db = LoadDatabase()
sortedStandings = [(k,v) for k,v in sorted(db.standings.items(),
                   key=lambda x: db.contests.loc[x[0]].startTime)]

# %%
from datetime import datetime

now = datetime.now()
 
print("now =", now)
# Out:
# now = 2021-02-06 18:14:24.127139

# %%
consider = -1

# %%
ans, userRatings = EloRatingSystem(db, consider=consider, errFunc = all_err_funs, verbose=True)
# Out:
# Standings left: 989 contestId: 26
# Standings left: 988 contestId: 27
# Standings left: 987 contestId: 28
# Standings left: 986 contestId: 29
# Standings left: 985 contestId: 30
# Standings left: 984 contestId: 31
# Standings left: 983 contestId: 32
# Standings left: 982 contestId: 33
# Standings left: 981 contestId: 34
# Standings left: 980 contestId: 35
# Standings left: 979 contestId: 36
# Standings left: 978 contestId: 37
# Standings left: 977 contestId: 40
# Standings left: 976 contestId: 41
# Standings left: 975 contestId: 42
# Standings left: 974 contestId: 43
# Standings left: 973 contestId: 47
# Standings left: 972 contestId: 49
# Standings left: 971 contestId: 51
# Standings left: 970 contestId: 53
# Standings left: 969 contestId: 54
# Standings left: 968 contestId: 55
# Standings left: 967 contestId: 56
# Standings left: 966 contestId: 57
# Standings left: 965 contestId: 58
# Standings left: 964 contestId: 59
# Standings left: 963 contestId: 60
# ...

# %%
now = datetime.now()
 
print("now =", now)
ans
# Out:
# now = 2021-02-07 05:13:20.991919
# {'sqrt_err': {26: 10.622356692278942,
#   27: 10.245837792604918,
#   28: 8.684613103914792,
#   29: 9.77097494180952,
#   30: 10.04112542145545,
#   31: 9.761503230321454,
#   32: 8.038425920419607,
#   33: 9.970246623190024,
#   34: 9.92295052693072,
#   35: 8.028336932507388,
#   36: 7.8922420250608605,
#   37: 10.54921221356113,
#   40: 10.450051575111734,
#   41: 10.079198665535655,
#   42: 9.868044673320234,
#   43: 9.522074543028058,
#   47: 9.496806965094702,
#   49: 9.296280666524043,
#   51: 9.588251392846622,
#   53: 8.346284892921473,
#   54: 7.940828900267621,
#   55: 8.270034475999363,
#   56: 10.036273376417382,
#   57: 9.648203864228488,
#   58: 10.46988315281401,
#   59: 9.533024674990914,
#   60: 10.749505495850356,
#   61: 9.858568354154125,
#   62: 5.56337616764801,
#   63: 9.338304697145638,
#   65: 12.068592203494681,
#   66: 10.795645187380702,
#   67: 11.239280553035163,
#   68: 11.617338925173554,
# ...

# %%
for err_fun_name in all_err_fun_names:
    errs = list(ans[err_fun_name].values())
    mean_err = np.mean(errs)
    std_err = np.std(errs)
    print(err_fun_name + ":", mean_err, "mean", "+-", std_err / 2, "stdev")
    
    plt.figure(figsize=(15, 8))
    plt.plot(errs)
    plt.xlabel("contest id")
    plt.ylabel("error")
    plt.title(err_fun_name)
    plt.show()
# Out:
# sqrt_err: 18.873759321330645 mean +- 4.774499376749239 stdev
# linear_err: 540.482170786376 mean +- 275.79070617469995 stdev
# log_err: 0.6431339016089408 mean +- 0.04683847378956822 stdev

# %%
def getPlaces(handle):
    ans = []
    for contestId, standings in sortedStandings[:consider]:
        if handle in standings.index:
            ans.append(standings.loc[handle]["rank"])
    return ans

def getRatings(handle):
    ans = []
    for contestId, standings in sortedStandings[:consider]:
        if handle in standings.index:
            ans.append(standings.loc[handle]["newRating"])
    return ans

def getRandomUser(threshold=20):
    x = np.random.choice([handle for handle, r in userRatings.items()])
    while len(userRatings[x].ratings) < threshold:
        x = np.random.choice([handle for handle, r in userRatings.items()])
    return x

def compareSystems(handle):
    eloRatings = userRatings[handle].ratings
    cfRatings = getRatings(handle)
    print("number of contests", len(cfRatings))
    assert len(eloRatings) == len(cfRatings)
    xs = np.arange(len(eloRatings))

    plt.figure(figsize=(15, 8))
    plt.plot(xs, eloRatings, label="EloRatings")
    plt.plot(xs, cfRatings, label="CodeForces")
    plt.title(handle)
    plt.legend()
    plt.show()

# %%
handle = 'mohammadkotb'
print(getPlaces(handle))
print(getRatings(handle))
print(userRatings[handle].ratings)
compareSystems(handle)
# Out:
# [415, 113, 322, 426, 56, 15, 374, 711, 97, 538, 534, 733, 999]
# [1263, 1406, 1517, 1447, 1571, 1648, 1574, 1502, 1637, 1568, 1523, 1445, 1378]
# [1038.5, 1173.2971104081632, 1230.4926421574487, 1109.0593774539755, 1253.2747084630475, 1426.322084319404, 1189.6988487197036, 865.9397474224827, 1700.7013131992549, 1283.7075785554266, 1331.23990569541, 1161.2973269650781, 965.3738817461256]
# number of contests 13

# %%
handle = getRandomUser()
compareSystems(handle)
# Out:
# number of contests 31

# %% [markdown]
# ### Finding optimal parameters

# %%
BasicRatings = np.linspace(1000, 2000, 10) #1200
#Ks = np.linspace(1, 10, 10) #1
Ks = np.linspace(0.15, 1, 10) #1
EloConst1s = np.linspace(1300, 1600, 3) #400
#EloConst1s = np.linspace(100, 500, 0) #400

# %%
consider = 200
save_file = f"save{consider}.pickle"

if os.path.exists(save_file):
    print("Loading file in ...")
    with open(save_file, "rb") as infile:
        all_results = pickle.load(infile)
    print("File loaded.")
else:
    all_results = {
        "BasicRatings": {},
        "Ks": {},
        "EloConst1s": {}
    }
# Out:
# Loading file in ...
# File loaded.

# %%
#It is not a problem that the calculation are interrupted
for BasicRating in BasicRatings:
    errors, results = EloRatingSystem(db, consider=consider, basicRating=BasicRating ,errFunc = all_err_funs, verbose=True)
    all_results["BasicRatings"][BasicRating] = errors
    
with open(save_file, "wb") as outfile:
    pickle.dump(all_results, outfile)
# Out:
# Standings left: 200 contestId: 26
# Standings left: 199 contestId: 27
# Standings left: 198 contestId: 28
# Standings left: 197 contestId: 29
# Standings left: 196 contestId: 30
# Standings left: 195 contestId: 31
# Standings left: 194 contestId: 32
# Standings left: 193 contestId: 33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-194-0e81816d9cd9> in <module>
#       1 for BasicRating in BasicRatings:
# ----> 2     errors, results = EloRatingSystem(db, consider=consider, basicRating=BasicRating ,errFunc = all_err_funs, verbose=True)
#       3     all_results["BasicRatings"][BasicRating] = errors
#       4
#       5 with open(save_file, "wb") as outfile:
#
# <ipython-input-152-e01d20be54dc> in EloRatingSystem(data, consider, verbose, basicRating, k, eloConst1, errFunc, **kwargs)
#     113
#     114         for handle in standings.index:
# ...

# %%
for K in Ks:
    errors, results = EloRatingSystem(db, consider=consider, k=K ,errFunc = all_err_funs, verbose=True)
    all_results["Ks"][K] = errors
    
with open(save_file, "wb") as outfile:
    pickle.dump(all_results, outfile)
# Out:
# Standings left: 200 contestId: 26
# Standings left: 199 contestId: 27
# Standings left: 198 contestId: 28
# Standings left: 197 contestId: 29
# Standings left: 196 contestId: 30
# Standings left: 195 contestId: 31
# Standings left: 194 contestId: 32
# Standings left: 193 contestId: 33
# Standings left: 192 contestId: 34
# Standings left: 191 contestId: 35
# Standings left: 190 contestId: 36
# Standings left: 189 contestId: 37
# Standings left: 188 contestId: 40
# Standings left: 187 contestId: 41
# Standings left: 186 contestId: 42
# Standings left: 185 contestId: 43
# Standings left: 184 contestId: 47
# Standings left: 183 contestId: 49
# Standings left: 182 contestId: 51
# Standings left: 181 contestId: 53
# Standings left: 180 contestId: 54
# Standings left: 179 contestId: 55
# Standings left: 178 contestId: 56
# Standings left: 177 contestId: 57
# Standings left: 176 contestId: 58
# Standings left: 175 contestId: 59
# Standings left: 174 contestId: 60
# ...

# %%
for EloConst1 in EloConst1s:
    errors, results = EloRatingSystem(db, consider=consider, eloConst1 = EloConst1 ,errFunc = all_err_funs, verbose=True)
    all_results["EloConst1s"][EloConst1] = errors
    
with open(save_file, "wb") as outfile:
    pickle.dump(all_results, outfile)
# Out:
# Standings left: 200 contestId: 26
# Standings left: 199 contestId: 27
# Standings left: 198 contestId: 28
# Standings left: 197 contestId: 29
# Standings left: 196 contestId: 30
# Standings left: 195 contestId: 31
# Standings left: 194 contestId: 32
# Standings left: 193 contestId: 33
# Standings left: 192 contestId: 34
# Standings left: 191 contestId: 35
# Standings left: 190 contestId: 36
# Standings left: 189 contestId: 37
# Standings left: 188 contestId: 40
# Standings left: 187 contestId: 41
# Standings left: 186 contestId: 42
# Standings left: 185 contestId: 43
# Standings left: 184 contestId: 47
# Standings left: 183 contestId: 49
# Standings left: 182 contestId: 51
# Standings left: 181 contestId: 53
# Standings left: 180 contestId: 54
# Standings left: 179 contestId: 55
# Standings left: 178 contestId: 56
# Standings left: 177 contestId: 57
# Standings left: 176 contestId: 58
# Standings left: 175 contestId: 59
# Standings left: 174 contestId: 60
# ...

# %% [markdown]
# ### Plots

# %%
# helper function
def get_ys(results, err_name, f):
    ys = []
    for val, all_errors in sorted(results.items(), key=lambda x: x[0]):
        errors = all_errors[err_name]
        vals = list(errors.values())
        ys.append(f(vals))
    return ys

# %%
# calculate statistics
stats = {}
for param_name, results in all_results.items():
    xs = sorted(list(results.keys()))
    param_dict = {}
    for err_name in all_err_fun_names:
        mean_ys = get_ys(results, err_name, np.mean)
        std_ys = get_ys(results, err_name, np.std)
        param_dict[err_name] = (xs, mean_ys, std_ys)
    stats[param_name] = param_dict

# %%
for param_name, param_dict in stats.items():
    fig, axs = plt.subplots(1, len(param_dict), figsize=(21, 5))
    for ax, (err_fun_name, (xs, mean_ys, std_ys)) in zip(axs, param_dict.items()):
        ax.title.set_text(f"mean error for \n parameter: {param_name} \n err_fun: {err_fun_name}")
        ax.set_xlabel("parameter value")
        ax.set_ylabel("error rate")
        ax.plot(xs, mean_ys)

# %%
for param_name, param_dict in stats.items():
    fig, axs = plt.subplots(1, len(param_dict), figsize=(21, 5))
    for ax, (err_fun_name, (xs, mean_ys, std_ys)) in zip(axs, param_dict.items()):
        ax.title.set_text(f"standard deviation of error for \n parameter: {param_name} \n err_fun: {err_fun_name}")
        ax.set_xlabel("parameter value")
        ax.set_ylabel("error rate")
        ax.plot(xs, std_ys)

# %% [markdown]
# ### Optimal parameter

# %%
def parameter_influence(param_name, param_vals, consider=200, **kwargs):
    res = {}
    for param_val in param_vals:
        kwargs[param_name] = param_val
        errors, results = EloRatingSystem(db,
            errFunc=all_err_funs,
            consider=consider,
            k=kwargs["k"],
            eloConst1=kwargs["eloConst1"])
        res[param_val] = errors
    return res

def plot_influence(param_name, influence, err_fun_name="log_err"):
    xs = list(influence.keys())
    ys = [np.mean(list(errors[err_fun_name].values())) for errors in influence.values()]
    plt.figure(figsize=(18, 5))
    plt.plot(xs, ys)
    plt.title(f"parameter {param_name} influence on error rate")
    plt.xlabel("parameter value")
    plt.ylabel("error rate")
    plt.show()
    
def get_opt_param_value(influence, err_fun_name="log_err"):
    param_vals = list(influence.keys())
    errors = [np.mean(list(errors[err_fun_name].values())) for errors in influence.values()]
    return param_vals[np.argmin(errors)]

# %%
# Ks = np.linspace(0.1, 2, 10)
Ks = np.linspace(0.2, 0.4, 5)

# %%
x_opt = [1.5, 400]
param_name = "k"
k_influence = parameter_influence(param_name, Ks, 200,
    k=1.5, eloConst1=400)

# %%
plot_influence(param_name, k_influence)

# %%
get_opt_param_value(k_influence)
# Out:
# 0.35000000000000003

# %%
k_opt = get_opt_param_value(k_influence)
EloConst1s = np.linspace(1000, 1600, 10) #400

# %%
x_opt = [k_opt, 400]
param_name = "eloConst1"
elo_const1_influence = parameter_influence(param_name, EloConst1s, 200,
    k=x_opt[0], eloConst1=x_opt[1])

# %%
plot_influence(param_name, elo_const1_influence)

# %%
get_opt_param_value(elo_const1_influence)
#We can interfere that EloConst1s depends on k
# Out:
# 400.0

# %%
EloConst1s = np.linspace(200, 1000, 5) #400

# %%
x_opt = [k_opt, 400]
param_name = "eloConst1"
elo_const1_influence = parameter_influence(param_name, EloConst1s, 200,
    k=x_opt[0], eloConst1=x_opt[1])

# %%
plot_influence(param_name, elo_const1_influence)

# %%
get_opt_param_value(elo_const1_influence)
# Out:
# 400.0

# %%
EloConst1s = np.linspace(300, 410, 5) #400

# %%
x_opt = [k_opt, 400]
param_name = "eloConst1"
elo_const1_influence = parameter_influence(param_name, EloConst1s, 200,
    k=x_opt[0], eloConst1=x_opt[1])

# %%
plot_influence(param_name, elo_const1_influence)

# %%
elo_const1_opt = get_opt_param_value(elo_const1_influence)

# %% [markdown]
# ## Results for the optimal parameters

# %%
x_opt = [k_opt, elo_const1_opt]
consider = -1

# %%
ans, userRatings = EloRatingSystem(db, consider=consider, k=x_opt[0], eloConst1=x_opt[1], errFunc = all_err_funs, verbose=True)
# Out:
# Standings left: 989 contestId: 26
# Standings left: 988 contestId: 27
# Standings left: 987 contestId: 28
# Standings left: 986 contestId: 29
# Standings left: 985 contestId: 30
# Standings left: 984 contestId: 31
# Standings left: 983 contestId: 32
# Standings left: 982 contestId: 33
# Standings left: 981 contestId: 34
# Standings left: 980 contestId: 35
# Standings left: 979 contestId: 36
# Standings left: 978 contestId: 37
# Standings left: 977 contestId: 40
# Standings left: 976 contestId: 41
# Standings left: 975 contestId: 42
# Standings left: 974 contestId: 43
# Standings left: 973 contestId: 47
# Standings left: 972 contestId: 49
# Standings left: 971 contestId: 51
# Standings left: 970 contestId: 53
# Standings left: 969 contestId: 54
# Standings left: 968 contestId: 55
# Standings left: 967 contestId: 56
# Standings left: 966 contestId: 57
# Standings left: 965 contestId: 58
# Standings left: 964 contestId: 59
# Standings left: 963 contestId: 60
# ...

# %%
for err_fun_name in all_err_fun_names:
    errs = list(ans[err_fun_name].values())
    mean_err = np.mean(errs)
    std_err = np.std(errs)
    print(err_fun_name + ":", mean_err, "mean", "+-", std_err / 2, "stdev")
    
    plt.figure(figsize=(15, 8))
    plt.plot(errs)
    plt.xlabel("contest id")
    plt.ylabel("error")
    plt.title(err_fun_name)
    plt.show()
# Out:
# sqrt_err: 18.484703361283707 mean +- 4.716465671374871 stdev
# linear_err: 520.616504501389 mean +- 270.56163823890074 stdev
# log_err: 0.6108963487010242 mean +- 0.04594707074323954 stdev
